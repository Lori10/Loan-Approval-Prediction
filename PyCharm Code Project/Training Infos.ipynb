# %%
import pandas as pd

pd.read_csv('model_infos.csv')
# Out:
#                                 Best Hyperparameters  \
# 0  {'subsample': 0.7, 'n_estimators': 100, 'min_c...
# 1  {'min_samples_split': 100, 'min_samples_leaf':...
# 2                        {'sampling_strategy': 0.64}
# 3  {'smotetomek__sampling_strategy': 0.36, 'estim...
#
#    Default Model CV Mean Score  \
# 0                     0.694728
# 1                     0.697542
# 2                     0.706708
# 3                     0.694823
#
#                              Default Model CV Scores  \
# 0  [0.69196554 0.69423167 0.69734809 0.69165257 0...
# 1  [0.69344254 0.69691839 0.70306214 0.69195397 0...
# 2  [0.7025595  0.70443642 0.71059609 0.70338174 0...
# 3  [0.68866409 0.69418807 0.69928719 0.69099598 0...
#
#                                 Default Model Object  \
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...
# 1  RandomForestClassifier(n_estimators=400, rando...
# 2  EasyEnsembleClassifier(base_estimator=XGBClass...
# ...
